# %% [markdown]
# <a href="https://www.kaggle.com/code/damlasogut/rule-based-classification?scriptVersionId=170483591" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Return on Lead Calculation with Rule Based Classification

# %% [markdown]
# * A gaming company wants to create level based personas by using some characteristics of its customers and create segments according to these new customer definitions and estimate how much new customers can earn the company on average according to these segments. For example: It is desired to determine how much a 25-year-old male IOS user from Turkey can earn on average.
# * Persona.csv dataset contains the prices of the products sold by an international gaming company and some demographic information of the users who purchased these products. The dataset consists of records that occur in each sales transaction. This means that the table is not deduplicated.

# %% [markdown]
# * Price: Customer's expenditure amount
# * Source: Type of device to which the customer is connected
# * Sex: Gender of the customer
# * Country: Country of the customer
# * Age: Age of the customer

# %% [markdown]
# # Question 1: Read the file persona.csv and show general information about the data set.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option("display.max_rows", None)
pd.set_option("display.expand_frame_repr",False)
pd.set_option("display.width", None)
df = pd.read_csv('/kaggle/input/persona/persona.csv')
df_copy=df.copy()
df.head()
# Out:
#    PRICE   SOURCE   SEX COUNTRY  AGE
# 0     39  android  male     bra   17
# 1     39  android  male     bra   17
# 2     49  android  male     bra   17
# 3     29  android  male     tur   17
# 4     49  android  male     tur   17

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5000 entries, 0 to 4999
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   PRICE    5000 non-null   int64
#  1   SOURCE   5000 non-null   object
#  2   SEX      5000 non-null   object
#  3   COUNTRY  5000 non-null   object
#  4   AGE      5000 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 234.4+ KB

# %%
df.columns
# Out:
# Index(['PRICE', 'SOURCE', 'SEX', 'COUNTRY', 'AGE'], dtype='object')

# %%
df.duplicated().sum()
# Out:
# 3616

# %%
df["SOURCE"].unique()
# Out:
# array(['android', 'ios'], dtype=object)

# %%
df["SOURCE"].nunique()
# Out:
# 2

# %%
# How many unique PRICE are there?
df["PRICE"].nunique()
# Out:
# 6

# %%
# How many sales were realised at which PRICE?
df["PRICE"].value_counts()
# Out:
# PRICE
# 29    1305
# 39    1260
# 49    1031
# 19     992
# 59     212
# 9      200
# Name: count, dtype: int64

# %%
#How many sales were there from which country?
df.groupby("COUNTRY")["PRICE"].count()
# Out:
# COUNTRY
# bra    1496
# can     230
# deu     455
# fra     303
# tur     451
# usa    2065
# Name: PRICE, dtype: int64

# %%
#What is the total amount earned from sales by country?
df.groupby("COUNTRY").agg({"PRICE": "sum"})
# Out:
#          PRICE
# COUNTRY
# bra      51354
# can       7730
# deu      15485
# fra      10177
# tur      15689
# usa      70225

# %%
#What is the number of sales according to SOURCE types?
df.groupby("SOURCE").agg({"PRICE" : "count"})
# Out:
#          PRICE
# SOURCE
# android   2974
# ios       2026

# %%
#What are the PRICE averages by country?
df.groupby(by=['COUNTRY']).agg({"PRICE": "mean"})
# Out:
#              PRICE
# COUNTRY
# bra      34.327540
# can      33.608696
# deu      34.032967
# fra      33.587459
# tur      34.787140
# usa      34.007264

# %%
#What is the average PRICE by SOURCE?
df.groupby(by=['SOURCE']).agg({"PRICE": "mean"})
# Out:
#              PRICE
# SOURCE
# android  34.174849
# ios      34.069102

# %%
#What are the PRICE averages in the COUNTRY-SOURCE breakdown?
df.groupby(by=["COUNTRY", 'SOURCE']).agg({"PRICE": "mean"})
# Out:
#                      PRICE
# COUNTRY SOURCE
# bra     android  34.387029
#         ios      34.222222
# can     android  33.330709
#         ios      33.951456
# deu     android  33.869888
#         ios      34.268817
# fra     android  34.312500
#         ios      32.776224
# tur     android  36.229437
#         ios      33.272727
# usa     android  33.760357
#         ios      34.371703

# %% [markdown]
# * TASK 2: What are the average earnings by COUNTRY, SOURCE, SEX, AGE?

# %%
df.groupby(["COUNTRY", 'SOURCE', "SEX", "AGE"]).agg({"PRICE": "mean"}). head(50)
# Out:
#                                 PRICE
# COUNTRY SOURCE  SEX    AGE
# bra     android female 15   38.714286
#                        16   35.944444
#                        17   35.666667
#                        18   32.255814
#                        19   35.206897
#                        20   31.000000
#                        21   37.292683
#                        22   34.945946
#                        23   31.941176
#                        24   36.500000
#                        25   35.666667
#                        26   33.166667
#                        27   26.142857
#                        28   22.333333
#                        29   37.571429
#                        30   45.666667
#                        31   35.097561
#                        32   39.000000
#                        34   24.000000
#                        37   33.736842
#                        38   34.555556
#                        39   43.000000
#                        41   32.333333
#                        43   44.000000
#                        45   33.615385
#                        56   37.000000
#                 male   15   39.344828
#                        16   29.666667
#                        17   37.157895
#                        18   33.054054
#                        19   35.216216
#                        20   35.400000
#                        21   35.250000
#                        22   31.000000
#                        23   21.500000
#                        24   40.428571
#                        25   30.428571
#                        26   37.095238
#                        27   32.636364
#                        28   28.230769
#                        29   29.714286
#                        30   35.363636
#                        35   31.500000
#                        36   31.857143
#                        40   39.625000
#                        41   35.666667
#                        44   36.500000
#                        46   59.000000
#                        53   29.000000
#         ios     female 15   36.777778

# %% [markdown]
# * TASK 3: Sort the output according to PRICE.

# %%
agg_df = df.groupby(by=["COUNTRY", 'SOURCE', "SEX", "AGE"]).agg({"PRICE": "mean"}).sort_values(by="PRICE", ascending=False)
agg_df.head()
# Out:
#                             PRICE
# COUNTRY SOURCE  SEX    AGE
# bra     android male   46    59.0
# usa     android male   36    59.0
# fra     android female 24    59.0
# usa     ios     male   32    54.0
# deu     android female 36    49.0

# %% [markdown]
# * * Convert the names in the index to variable names.

# %%
agg_df = agg_df.reset_index()

# %% [markdown]
# * TASK 5: Convert the variable AGE into a categorical variable and add it to agg_df.

# %%
age_bins= [0, 18 ,23 ,30 , 40, 66]
labels=['0-18','19-23','24-30','31-40','41-66']
agg_df["AGE_CAT"]= pd.cut(agg_df["AGE"],bins=age_bins,labels=labels,right=True) 
agg_df["AGE_CAT"].head()
# Out:
# 0    41-66
# 1    31-40
# 2    24-30
# 3    31-40
# 4    31-40
# Name: AGE_CAT, dtype: category
# Categories (5, object): ['0-18' < '19-23' < '24-30' < '31-40' < '41-66']

# %% [markdown]
# *  TASK 6: Define new level based customers and add them as variables to the data set.

# %%
agg_df["customers_level_based"] = ['_'.join(i).upper() for i in agg_df.drop(["AGE", "PRICE"], axis=1).values]

agg_df.head()
# Out:
#   COUNTRY   SOURCE     SEX  AGE  PRICE AGE_CAT     customers_level_based
# 0     bra  android    male   46   59.0   41-66    BRA_ANDROID_MALE_41-66
# 1     usa  android    male   36   59.0   31-40    USA_ANDROID_MALE_31-40
# 2     fra  android  female   24   59.0   24-30  FRA_ANDROID_FEMALE_24-30
# 3     usa      ios    male   32   54.0   31-40        USA_IOS_MALE_31-40
# 4     deu  android  female   36   49.0   31-40  DEU_ANDROID_FEMALE_31-40

# %%
for row in agg_df.values:
    print(row)
# Out:
# ['bra' 'android' 'male' 46 59.0 '41-66' 'BRA_ANDROID_MALE_41-66']
# ['usa' 'android' 'male' 36 59.0 '31-40' 'USA_ANDROID_MALE_31-40']
# ['fra' 'android' 'female' 24 59.0 '24-30' 'FRA_ANDROID_FEMALE_24-30']
# ['usa' 'ios' 'male' 32 54.0 '31-40' 'USA_IOS_MALE_31-40']
# ['deu' 'android' 'female' 36 49.0 '31-40' 'DEU_ANDROID_FEMALE_31-40']
# ['deu' 'android' 'female' 51 49.0 '41-66' 'DEU_ANDROID_FEMALE_41-66']
# ['deu' 'ios' 'male' 20 49.0 '19-23' 'DEU_IOS_MALE_19-23']
# ['usa' 'android' 'female' 47 49.0 '41-66' 'USA_ANDROID_FEMALE_41-66']
# ['fra' 'ios' 'male' 20 49.0 '19-23' 'FRA_IOS_MALE_19-23']
# ['usa' 'ios' 'male' 59 46.5 '41-66' 'USA_IOS_MALE_41-66']
# ['deu' 'android' 'male' 15 46.5 '0-18' 'DEU_ANDROID_MALE_0-18']
# ['bra' 'android' 'female' 30 45.666666666666664 '24-30'
#  'BRA_ANDROID_FEMALE_24-30']
# ['usa' 'android' 'female' 61 45.666666666666664 '41-66'
#  'USA_ANDROID_FEMALE_41-66']
# ['tur' 'ios' 'male' 24 45.0 '24-30' 'TUR_IOS_MALE_24-30']
# ['deu' 'android' 'male' 34 45.0 '31-40' 'DEU_ANDROID_MALE_31-40']
# ['tur' 'ios' 'female' 18 44.0 '0-18' 'TUR_IOS_FEMALE_0-18']
# ['bra' 'android' 'female' 43 44.0 '41-66' 'BRA_ANDROID_FEMALE_41-66']
# ['bra' 'ios' 'female' 22 44.0 '19-23' 'BRA_IOS_FEMALE_19-23']
# ['tur' 'android' 'female' 32 43.0 '31-40' 'TUR_ANDROID_FEMALE_31-40']
# ['bra' 'android' 'female' 39 43.0 '31-40' 'BRA_ANDROID_FEMALE_31-40']
# ['tur' 'ios' 'male' 37 42.333333333333336 '31-40' 'TUR_IOS_MALE_31-40']
# ['tur' 'android' 'male' 15 42.333333333333336 '0-18'
#  'TUR_ANDROID_MALE_0-18']
# ['usa' 'ios' 'male' 28 42.333333333333336 '24-30' 'USA_IOS_MALE_24-30']
# ['bra' 'ios' 'male' 43 42.333333333333336 '41-66' 'BRA_IOS_MALE_41-66']
# ['deu' 'android' 'male' 20 41.72727272727273 '19-23'
#  'DEU_ANDROID_MALE_19-23']
# ['usa' 'ios' 'male' 30 41.72727272727273 '24-30' 'USA_IOS_MALE_24-30']
# ['tur' 'android' 'female' 18 41.5 '0-18' 'TUR_ANDROID_FEMALE_0-18']
# ['usa' 'android' 'male' 47 41.5 '41-66' 'USA_ANDROID_MALE_41-66']
# ['tur' 'android' 'male' 25 41.5 '24-30' 'TUR_ANDROID_MALE_24-30']
# ['usa' 'ios' 'female' 59 41.5 '41-66' 'USA_IOS_FEMALE_41-66']
# ['fra' 'android' 'male' 23 41.30769230769231 '19-23'
#  'FRA_ANDROID_MALE_19-23']
# ['usa' 'ios' 'male' 31 41.0 '31-40' 'USA_IOS_MALE_31-40']
# ['tur' 'android' 'female' 15 41.0 '0-18' 'TUR_ANDROID_FEMALE_0-18']
# ['fra' 'ios' 'male' 17 40.666666666666664 '0-18' 'FRA_IOS_MALE_0-18']
# ['tur' 'ios' 'female' 21 40.666666666666664 '19-23' 'TUR_IOS_FEMALE_19-23']
# ['tur' 'android' 'female' 31 40.666666666666664 '31-40'
#  'TUR_ANDROID_FEMALE_31-40']
# ['tur' 'android' 'male' 27 40.666666666666664 '24-30'
#  'TUR_ANDROID_MALE_24-30']
# ['fra' 'android' 'male' 19 40.53846153846154 '19-23'
#  'FRA_ANDROID_MALE_19-23']
# ['bra' 'android' 'male' 24 40.42857142857143 '24-30'
#  'BRA_ANDROID_MALE_24-30']
# ['can' 'android' 'male' 30 40.25 '24-30' 'CAN_ANDROID_MALE_24-30']
# ['can' 'android' 'male' 20 40.111111111111114 '19-23'
#  'CAN_ANDROID_MALE_19-23']
# ['usa' 'android' 'male' 43 39.90909090909091 '41-66'
#  'USA_ANDROID_MALE_41-66']
# ['tur' 'android' 'male' 26 39.666666666666664 '24-30'
#  'TUR_ANDROID_MALE_24-30']
# ['bra' 'android' 'male' 40 39.625 '31-40' 'BRA_ANDROID_MALE_31-40']
# ['bra' 'android' 'male' 15 39.3448275862069 '0-18' 'BRA_ANDROID_MALE_0-18']
# ['usa' 'ios' 'female' 19 39.285714285714285 '19-23' 'USA_IOS_FEMALE_19-23']
# ['tur' 'android' 'male' 49 39.0 '41-66' 'TUR_ANDROID_MALE_41-66']
# ['bra' 'ios' 'female' 19 39.0 '19-23' 'BRA_IOS_FEMALE_19-23']
# ['usa' 'ios' 'male' 50 39.0 '41-66' 'USA_IOS_MALE_41-66']
# ['bra' 'ios' 'female' 25 39.0 '24-30' 'BRA_IOS_FEMALE_24-30']
# ['deu' 'android' 'female' 38 39.0 '31-40' 'DEU_ANDROID_FEMALE_31-40']
# ['deu' 'ios' 'male' 16 39.0 '0-18' 'DEU_IOS_MALE_0-18']
# ['fra' 'android' 'female' 21 39.0 '19-23' 'FRA_ANDROID_FEMALE_19-23']
# ['fra' 'android' 'male' 33 39.0 '31-40' 'FRA_ANDROID_MALE_31-40']
# ['tur' 'ios' 'female' 31 39.0 '31-40' 'TUR_IOS_FEMALE_31-40']
# ['fra' 'ios' 'male' 51 39.0 '41-66' 'FRA_IOS_MALE_41-66']
# ['bra' 'android' 'female' 32 39.0 '31-40' 'BRA_ANDROID_FEMALE_31-40']
# ['tur' 'ios' 'male' 16 39.0 '0-18' 'TUR_IOS_MALE_0-18']
# ['bra' 'ios' 'female' 42 39.0 '41-66' 'BRA_IOS_FEMALE_41-66']
# ['tur' 'android' 'male' 17 39.0 '0-18' 'TUR_ANDROID_MALE_0-18']
# ['tur' 'android' 'female' 49 39.0 '41-66' 'TUR_ANDROID_FEMALE_41-66']
# ['bra' 'android' 'female' 15 38.714285714285715 '0-18'
#  'BRA_ANDROID_FEMALE_0-18']
# ['usa' 'ios' 'male' 21 38.53488372093023 '19-23' 'USA_IOS_MALE_19-23']
# ['usa' 'ios' 'female' 17 38.45945945945946 '0-18' 'USA_IOS_FEMALE_0-18']
# ['fra' 'ios' 'male' 31 38.375 '31-40' 'FRA_IOS_MALE_31-40']
# ['tur' 'android' 'male' 16 38.285714285714285 '0-18'
#  'TUR_ANDROID_MALE_0-18']
# ['deu' 'android' 'male' 37 38.166666666666664 '31-40'
#  'DEU_ANDROID_MALE_31-40']
# ['usa' 'ios' 'female' 25 38.0 '24-30' 'USA_IOS_FEMALE_24-30']
# ['deu' 'ios' 'female' 17 37.8235294117647 '0-18' 'DEU_IOS_FEMALE_0-18']
# ['can' 'ios' 'male' 17 37.666666666666664 '0-18' 'CAN_IOS_MALE_0-18']
# ['can' 'android' 'male' 49 37.57142857142857 '41-66'
#  'CAN_ANDROID_MALE_41-66']
# ['bra' 'android' 'female' 29 37.57142857142857 '24-30'
#  'BRA_ANDROID_FEMALE_24-30']
# ['tur' 'android' 'female' 26 37.57142857142857 '24-30'
#  'TUR_ANDROID_FEMALE_24-30']
# ['can' 'ios' 'male' 15 37.57142857142857 '0-18' 'CAN_IOS_MALE_0-18']
# ['bra' 'ios' 'male' 33 37.57142857142857 '31-40' 'BRA_IOS_MALE_31-40']
# ['fra' 'android' 'female' 15 37.57142857142857 '0-18'
#  'FRA_ANDROID_FEMALE_0-18']
# ['deu' 'ios' 'female' 18 37.333333333333336 '0-18' 'DEU_IOS_FEMALE_0-18']
# ['can' 'android' 'female' 18 37.333333333333336 '0-18'
#  'CAN_ANDROID_FEMALE_0-18']
# ['tur' 'ios' 'female' 20 37.333333333333336 '19-23' 'TUR_IOS_FEMALE_19-23']
# ['deu' 'android' 'male' 23 37.333333333333336 '19-23'
#  'DEU_ANDROID_MALE_19-23']
# ['bra' 'android' 'female' 21 37.292682926829265 '19-23'
#  'BRA_ANDROID_FEMALE_19-23']
# ['usa' 'android' 'female' 33 37.18181818181818 '31-40'
#  'USA_ANDROID_FEMALE_31-40']
# ['bra' 'ios' 'male' 22 37.18181818181818 '19-23' 'BRA_IOS_MALE_19-23']
# ['bra' 'android' 'male' 17 37.1578947368421 '0-18' 'BRA_ANDROID_MALE_0-18']
# ['bra' 'android' 'male' 26 37.095238095238095 '24-30'
#  'BRA_ANDROID_MALE_24-30']
# ['usa' 'android' 'male' 26 37.0 '24-30' 'USA_ANDROID_MALE_24-30']
# ['tur' 'android' 'female' 21 37.0 '19-23' 'TUR_ANDROID_FEMALE_19-23']
# ['deu' 'ios' 'male' 42 37.0 '41-66' 'DEU_IOS_MALE_41-66']
# ['bra' 'android' 'female' 56 37.0 '41-66' 'BRA_ANDROID_FEMALE_41-66']
# ['bra' 'ios' 'male' 15 36.878787878787875 '0-18' 'BRA_IOS_MALE_0-18']
# ['usa' 'ios' 'female' 26 36.857142857142854 '24-30' 'USA_IOS_FEMALE_24-30']
# ['bra' 'ios' 'female' 15 36.77777777777778 '0-18' 'BRA_IOS_FEMALE_0-18']
# ['bra' 'ios' 'male' 35 36.77777777777778 '31-40' 'BRA_IOS_MALE_31-40']
# ['fra' 'android' 'female' 16 36.72727272727273 '0-18'
#  'FRA_ANDROID_FEMALE_0-18']
# ['usa' 'android' 'male' 20 36.64705882352941 '19-23'
#  'USA_ANDROID_MALE_19-23']
# ['bra' 'ios' 'female' 18 36.5 '0-18' 'BRA_IOS_FEMALE_0-18']
# ['bra' 'android' 'male' 44 36.5 '41-66' 'BRA_ANDROID_MALE_41-66']
# ['bra' 'android' 'female' 24 36.5 '24-30' 'BRA_ANDROID_FEMALE_24-30']
# ['usa' 'android' 'male' 30 36.142857142857146 '24-30'
#  'USA_ANDROID_MALE_24-30']
# ['tur' 'android' 'female' 52 36.142857142857146 '41-66'
#  'TUR_ANDROID_FEMALE_41-66']
# ['usa' 'ios' 'female' 28 36.142857142857146 '24-30' 'USA_IOS_FEMALE_24-30']
# ['deu' 'ios' 'female' 26 36.0 '24-30' 'DEU_IOS_FEMALE_24-30']
# ['can' 'android' 'male' 15 36.0 '0-18' 'CAN_ANDROID_MALE_0-18']
# ['bra' 'android' 'female' 16 35.94444444444444 '0-18'
#  'BRA_ANDROID_FEMALE_0-18']
# ['tur' 'android' 'male' 24 35.92307692307692 '24-30'
#  'TUR_ANDROID_MALE_24-30']
# ['usa' 'android' 'male' 51 35.875 '41-66' 'USA_ANDROID_MALE_41-66']
# ['usa' 'ios' 'female' 21 35.8 '19-23' 'USA_IOS_FEMALE_19-23']
# ['usa' 'android' 'female' 19 35.76470588235294 '19-23'
#  'USA_ANDROID_FEMALE_19-23']
# ['fra' 'ios' 'male' 19 35.666666666666664 '19-23' 'FRA_IOS_MALE_19-23']
# ['fra' 'android' 'male' 55 35.666666666666664 '41-66'
#  'FRA_ANDROID_MALE_41-66']
# ['bra' 'android' 'male' 41 35.666666666666664 '41-66'
#  'BRA_ANDROID_MALE_41-66']
# ['tur' 'android' 'male' 22 35.666666666666664 '19-23'
#  'TUR_ANDROID_MALE_19-23']
# ['bra' 'android' 'female' 25 35.666666666666664 '24-30'
#  'BRA_ANDROID_FEMALE_24-30']
# ['usa' 'android' 'female' 35 35.666666666666664 '31-40'
#  'USA_ANDROID_FEMALE_31-40']
# ['usa' 'ios' 'female' 29 35.666666666666664 '24-30' 'USA_IOS_FEMALE_24-30']
# ['bra' 'android' 'female' 17 35.666666666666664 '0-18'
#  'BRA_ANDROID_FEMALE_0-18']
# ['tur' 'ios' 'female' 19 35.666666666666664 '19-23' 'TUR_IOS_FEMALE_19-23']
# ['deu' 'ios' 'female' 16 35.557377049180324 '0-18' 'DEU_IOS_FEMALE_0-18']
# ['usa' 'android' 'male' 41 35.42857142857143 '41-66'
#  'USA_ANDROID_MALE_41-66']
# ['bra' 'android' 'male' 20 35.4 '19-23' 'BRA_ANDROID_MALE_19-23']
# ['deu' 'android' 'male' 33 35.36363636363637 '31-40'
#  'DEU_ANDROID_MALE_31-40']
# ['bra' 'ios' 'female' 33 35.36363636363637 '31-40' 'BRA_IOS_FEMALE_31-40']
# ['bra' 'ios' 'female' 45 35.36363636363637 '41-66' 'BRA_IOS_FEMALE_41-66']
# ['bra' 'android' 'male' 30 35.36363636363637 '24-30'
#  'BRA_ANDROID_MALE_24-30']
# ['deu' 'android' 'female' 24 35.36363636363637 '24-30'
#  'DEU_ANDROID_FEMALE_24-30']
# ['bra' 'ios' 'male' 17 35.333333333333336 '0-18' 'BRA_IOS_MALE_0-18']
# ['bra' 'android' 'male' 21 35.25 '19-23' 'BRA_ANDROID_MALE_19-23']
# ['usa' 'android' 'female' 49 35.25 '41-66' 'USA_ANDROID_FEMALE_41-66']
# ['bra' 'android' 'male' 19 35.21621621621622 '19-23'
#  'BRA_ANDROID_MALE_19-23']
# ['bra' 'android' 'female' 19 35.206896551724135 '19-23'
#  'BRA_ANDROID_FEMALE_19-23']
# ['usa' 'android' 'male' 18 35.19047619047619 '0-18'
#  'USA_ANDROID_MALE_0-18']
# ['bra' 'ios' 'female' 37 35.111111111111114 '31-40' 'BRA_IOS_FEMALE_31-40']
# ['usa' 'ios' 'male' 27 35.111111111111114 '24-30' 'USA_IOS_MALE_24-30']
# ['bra' 'android' 'female' 31 35.09756097560975 '31-40'
#  'BRA_ANDROID_FEMALE_31-40']
# ['usa' 'ios' 'female' 20 35.0 '19-23' 'USA_IOS_FEMALE_19-23']
# ['usa' 'android' 'female' 31 35.0 '31-40' 'USA_ANDROID_FEMALE_31-40']
# ['fra' 'ios' 'male' 22 35.0 '19-23' 'FRA_IOS_MALE_19-23']
# ['deu' 'android' 'female' 22 35.0 '19-23' 'DEU_ANDROID_FEMALE_19-23']
# ['can' 'ios' 'male' 16 35.0 '0-18' 'CAN_IOS_MALE_0-18']
# ['deu' 'ios' 'male' 17 35.0 '0-18' 'DEU_IOS_MALE_0-18']
# ['usa' 'ios' 'female' 65 35.0 '41-66' 'USA_IOS_FEMALE_41-66']
# ['deu' 'ios' 'male' 25 35.0 '24-30' 'DEU_IOS_MALE_24-30']
# ['bra' 'android' 'female' 22 34.945945945945944 '19-23'
#  'BRA_ANDROID_FEMALE_19-23']
# ['usa' 'android' 'female' 16 34.90163934426229 '0-18'
#  'USA_ANDROID_FEMALE_0-18']
# ['bra' 'ios' 'male' 23 34.88235294117647 '19-23' 'BRA_IOS_MALE_19-23']
# ['usa' 'android' 'male' 23 34.84905660377358 '19-23'
#  'USA_ANDROID_MALE_19-23']
# ['tur' 'ios' 'male' 17 34.806451612903224 '0-18' 'TUR_IOS_MALE_0-18']
# ['usa' 'android' 'female' 28 34.78947368421053 '24-30'
#  'USA_ANDROID_FEMALE_24-30']
# ['usa' 'ios' 'male' 16 34.714285714285715 '0-18' 'USA_IOS_MALE_0-18']
# ['bra' 'ios' 'male' 34 34.714285714285715 '31-40' 'BRA_IOS_MALE_31-40']
# ['usa' 'android' 'male' 22 34.714285714285715 '19-23'
#  'USA_ANDROID_MALE_19-23']
# ['usa' 'android' 'male' 35 34.714285714285715 '31-40'
#  'USA_ANDROID_MALE_31-40']
# ['usa' 'android' 'male' 31 34.714285714285715 '31-40'
#  'USA_ANDROID_MALE_31-40']
# ['usa' 'ios' 'female' 47 34.714285714285715 '41-66' 'USA_IOS_FEMALE_41-66']
# ['usa' 'android' 'male' 15 34.663716814159294 '0-18'
#  'USA_ANDROID_MALE_0-18']
# ['fra' 'android' 'female' 17 34.65217391304348 '0-18'
#  'FRA_ANDROID_FEMALE_0-18']
# ['usa' 'android' 'female' 17 34.625 '0-18' 'USA_ANDROID_FEMALE_0-18']
# ['usa' 'ios' 'male' 18 34.57692307692308 '0-18' 'USA_IOS_MALE_0-18']
# ['bra' 'android' 'female' 38 34.55555555555556 '31-40'
#  'BRA_ANDROID_FEMALE_31-40']
# ['usa' 'ios' 'female' 33 34.55555555555556 '31-40' 'USA_IOS_FEMALE_31-40']
# ['tur' 'android' 'female' 16 34.55555555555556 '0-18'
#  'TUR_ANDROID_FEMALE_0-18']
# ['deu' 'android' 'female' 25 34.45454545454545 '24-30'
#  'DEU_ANDROID_FEMALE_24-30']
# ['usa' 'android' 'male' 17 34.45454545454545 '0-18'
#  'USA_ANDROID_MALE_0-18']
# ['usa' 'android' 'male' 28 34.38461538461539 '24-30'
#  'USA_ANDROID_MALE_24-30']
# ['bra' 'ios' 'female' 26 34.333333333333336 '24-30' 'BRA_IOS_FEMALE_24-30']
# ['usa' 'android' 'female' 21 34.18518518518518 '19-23'
#  'USA_ANDROID_FEMALE_19-23']
# ['bra' 'ios' 'female' 54 34.0 '41-66' 'BRA_IOS_FEMALE_41-66']
# ['deu' 'android' 'female' 23 34.0 '19-23' 'DEU_ANDROID_FEMALE_19-23']
# ['usa' 'ios' 'male' 26 34.0 '24-30' 'USA_IOS_MALE_24-30']
# ['fra' 'ios' 'male' 26 34.0 '24-30' 'FRA_IOS_MALE_24-30']
# ['bra' 'ios' 'female' 27 34.0 '24-30' 'BRA_IOS_FEMALE_24-30']
# ['can' 'android' 'female' 43 34.0 '41-66' 'CAN_ANDROID_FEMALE_41-66']
# ['usa' 'ios' 'female' 22 34.0 '19-23' 'USA_IOS_FEMALE_19-23']
# ['usa' 'ios' 'male' 20 34.0 '19-23' 'USA_IOS_MALE_19-23']
# ['bra' 'ios' 'male' 19 34.0 '19-23' 'BRA_IOS_MALE_19-23']
# ['tur' 'ios' 'female' 23 34.0 '19-23' 'TUR_IOS_FEMALE_19-23']
# ['tur' 'ios' 'female' 25 34.0 '24-30' 'TUR_IOS_FEMALE_24-30']
# ['tur' 'ios' 'female' 26 34.0 '24-30' 'TUR_IOS_FEMALE_24-30']
# ['deu' 'ios' 'female' 22 34.0 '19-23' 'DEU_IOS_FEMALE_19-23']
# ['tur' 'ios' 'female' 51 34.0 '41-66' 'TUR_IOS_FEMALE_41-66']
# ['deu' 'android' 'male' 21 34.0 '19-23' 'DEU_ANDROID_MALE_19-23']
# ['bra' 'ios' 'female' 24 34.0 '24-30' 'BRA_IOS_FEMALE_24-30']
# ['usa' 'android' 'male' 16 34.0 '0-18' 'USA_ANDROID_MALE_0-18']
# ['usa' 'ios' 'male' 53 34.0 '41-66' 'USA_IOS_MALE_41-66']
# ['usa' 'android' 'female' 42 34.0 '41-66' 'USA_ANDROID_FEMALE_41-66']
# ['fra' 'android' 'female' 35 34.0 '31-40' 'FRA_ANDROID_FEMALE_31-40']
# ['usa' 'android' 'male' 25 34.0 '24-30' 'USA_ANDROID_MALE_24-30']
# ['usa' 'android' 'female' 25 34.0 '24-30' 'USA_ANDROID_FEMALE_24-30']
# ['deu' 'ios' 'female' 23 34.0 '19-23' 'DEU_IOS_FEMALE_19-23']
# ['bra' 'ios' 'male' 24 33.86486486486486 '24-30' 'BRA_IOS_MALE_24-30']
# ['usa' 'ios' 'female' 15 33.857142857142854 '0-18' 'USA_IOS_FEMALE_0-18']
# ['usa' 'android' 'female' 22 33.8 '19-23' 'USA_ANDROID_FEMALE_19-23']
# ['bra' 'ios' 'male' 16 33.76190476190476 '0-18' 'BRA_IOS_MALE_0-18']
# ['deu' 'android' 'female' 17 33.73684210526316 '0-18'
#  'DEU_ANDROID_FEMALE_0-18']
# ['bra' 'android' 'female' 37 33.73684210526316 '31-40'
#  'BRA_ANDROID_FEMALE_31-40']
# ['usa' 'ios' 'male' 15 33.729729729729726 '0-18' 'USA_IOS_MALE_0-18']
# ['can' 'ios' 'female' 15 33.705882352941174 '0-18' 'CAN_IOS_FEMALE_0-18']
# ['tur' 'android' 'female' 17 33.6875 '0-18' 'TUR_ANDROID_FEMALE_0-18']
# ['bra' 'ios' 'female' 16 33.6875 '0-18' 'BRA_IOS_FEMALE_0-18']
# ['fra' 'ios' 'female' 15 33.61538461538461 '0-18' 'FRA_IOS_FEMALE_0-18']
# ['bra' 'android' 'female' 45 33.61538461538461 '41-66'
#  'BRA_ANDROID_FEMALE_41-66']
# ['bra' 'ios' 'male' 44 33.54545454545455 '41-66' 'BRA_IOS_MALE_41-66']
# ['usa' 'android' 'male' 27 33.285714285714285 '24-30'
#  'USA_ANDROID_MALE_24-30']
# ['bra' 'android' 'female' 26 33.166666666666664 '24-30'
#  'BRA_ANDROID_FEMALE_24-30']
# ['usa' 'android' 'female' 23 33.1025641025641 '19-23'
#  'USA_ANDROID_FEMALE_19-23']
# ['bra' 'android' 'male' 18 33.054054054054056 '0-18'
#  'BRA_ANDROID_MALE_0-18']
# ['bra' 'ios' 'female' 46 33.0 '41-66' 'BRA_IOS_FEMALE_41-66']
# ['usa' 'android' 'male' 42 33.0 '41-66' 'USA_ANDROID_MALE_41-66']
# ['fra' 'ios' 'female' 40 33.0 '31-40' 'FRA_IOS_FEMALE_31-40']
# ['fra' 'android' 'male' 25 33.0 '24-30' 'FRA_ANDROID_MALE_24-30']
# ['deu' 'ios' 'female' 32 33.0 '31-40' 'DEU_IOS_FEMALE_31-40']
# ['usa' 'ios' 'female' 18 32.91304347826087 '0-18' 'USA_IOS_FEMALE_0-18']
# ['deu' 'android' 'male' 17 32.91304347826087 '0-18'
#  'DEU_ANDROID_MALE_0-18']
# ['usa' 'ios' 'male' 17 32.91304347826087 '0-18' 'USA_IOS_MALE_0-18']
# ['bra' 'ios' 'female' 20 32.84615384615385 '19-23' 'BRA_IOS_FEMALE_19-23']
# ['tur' 'ios' 'male' 15 32.84615384615385 '0-18' 'TUR_IOS_MALE_0-18']
# ['usa' 'android' 'male' 19 32.80952380952381 '19-23'
#  'USA_ANDROID_MALE_19-23']
# ['usa' 'ios' 'female' 23 32.80952380952381 '19-23' 'USA_IOS_FEMALE_19-23']
# ['usa' 'ios' 'female' 24 32.75 '24-30' 'USA_IOS_FEMALE_24-30']
# ['bra' 'ios' 'male' 18 32.68421052631579 '0-18' 'BRA_IOS_MALE_0-18']
# ['usa' 'android' 'female' 15 32.666666666666664 '0-18'
#  'USA_ANDROID_FEMALE_0-18']
# ['fra' 'ios' 'female' 31 32.63636363636363 '31-40' 'FRA_IOS_FEMALE_31-40']
# ['bra' 'ios' 'female' 17 32.63636363636363 '0-18' 'BRA_IOS_FEMALE_0-18']
# ['tur' 'ios' 'female' 22 32.63636363636363 '19-23' 'TUR_IOS_FEMALE_19-23']
# ['bra' 'android' 'male' 27 32.63636363636363 '24-30'
#  'BRA_ANDROID_MALE_24-30']
# ['fra' 'ios' 'female' 18 32.57142857142857 '0-18' 'FRA_IOS_FEMALE_0-18']
# ['can' 'android' 'female' 19 32.529411764705884 '19-23'
#  'CAN_ANDROID_FEMALE_19-23']
# ['usa' 'android' 'female' 18 32.40425531914894 '0-18'
#  'USA_ANDROID_FEMALE_0-18']
# ['deu' 'android' 'male' 18 32.333333333333336 '0-18'
#  'DEU_ANDROID_MALE_0-18']
# ['usa' 'android' 'male' 21 32.333333333333336 '19-23'
#  'USA_ANDROID_MALE_19-23']
# ['deu' 'android' 'female' 34 32.333333333333336 '31-40'
#  'DEU_ANDROID_FEMALE_31-40']
# ['usa' 'android' 'female' 44 32.333333333333336 '41-66'
#  'USA_ANDROID_FEMALE_41-66']
# ['fra' 'android' 'male' 32 32.333333333333336 '31-40'
#  'FRA_ANDROID_MALE_31-40']
# ['deu' 'android' 'female' 28 32.333333333333336 '24-30'
#  'DEU_ANDROID_FEMALE_24-30']
# ['fra' 'android' 'male' 46 32.333333333333336 '41-66'
#  'FRA_ANDROID_MALE_41-66']
# ['bra' 'ios' 'female' 28 32.333333333333336 '24-30' 'BRA_IOS_FEMALE_24-30']
# ['deu' 'android' 'male' 31 32.333333333333336 '31-40'
#  'DEU_ANDROID_MALE_31-40']
# ['tur' 'android' 'female' 20 32.333333333333336 '19-23'
#  'TUR_ANDROID_FEMALE_19-23']
# ['tur' 'android' 'female' 50 32.333333333333336 '41-66'
#  'TUR_ANDROID_FEMALE_41-66']
# ['bra' 'android' 'female' 41 32.333333333333336 '41-66'
#  'BRA_ANDROID_FEMALE_41-66']
# ['bra' 'ios' 'female' 35 32.333333333333336 '31-40' 'BRA_IOS_FEMALE_31-40']
# ['bra' 'android' 'female' 18 32.25581395348837 '0-18'
#  'BRA_ANDROID_FEMALE_0-18']
# ['usa' 'ios' 'male' 22 32.170731707317074 '19-23' 'USA_IOS_MALE_19-23']
# ['fra' 'android' 'female' 23 32.125 '19-23' 'FRA_ANDROID_FEMALE_19-23']
# ['deu' 'android' 'female' 27 32.125 '24-30' 'DEU_ANDROID_FEMALE_24-30']
# ['deu' 'android' 'female' 15 32.0 '0-18' 'DEU_ANDROID_FEMALE_0-18']
# ['bra' 'android' 'female' 23 31.941176470588236 '19-23'
#  'BRA_ANDROID_FEMALE_19-23']
# ['usa' 'ios' 'male' 25 31.857142857142858 '24-30' 'USA_IOS_MALE_24-30']
# ['bra' 'android' 'male' 36 31.857142857142858 '31-40'
#  'BRA_ANDROID_MALE_31-40']
# ['fra' 'android' 'female' 26 31.857142857142858 '24-30'
#  'FRA_ANDROID_FEMALE_24-30']
# ['usa' 'ios' 'male' 37 31.727272727272727 '31-40' 'USA_IOS_MALE_31-40']
# ['can' 'ios' 'female' 29 31.727272727272727 '24-30' 'CAN_IOS_FEMALE_24-30']
# ['can' 'android' 'female' 20 31.5 '19-23' 'CAN_ANDROID_FEMALE_19-23']
# ['usa' 'ios' 'female' 27 31.5 '24-30' 'USA_IOS_FEMALE_24-30']
# ['bra' 'android' 'male' 35 31.5 '31-40' 'BRA_ANDROID_MALE_31-40']
# ['usa' 'ios' 'female' 16 31.5 '0-18' 'USA_IOS_FEMALE_0-18']
# ['deu' 'android' 'female' 44 31.5 '41-66' 'DEU_ANDROID_FEMALE_41-66']
# ['deu' 'ios' 'male' 32 31.352941176470587 '31-40' 'DEU_IOS_MALE_31-40']
# ['usa' 'android' 'female' 20 31.285714285714285 '19-23'
#  'USA_ANDROID_FEMALE_19-23']
# ['deu' 'android' 'male' 19 31.22222222222222 '19-23'
#  'DEU_ANDROID_MALE_19-23']
# ['can' 'ios' 'male' 25 31.17391304347826 '24-30' 'CAN_IOS_MALE_24-30']
# ['tur' 'ios' 'male' 42 31.105263157894736 '41-66' 'TUR_IOS_MALE_41-66']
# ['can' 'ios' 'male' 57 31.0 '41-66' 'CAN_IOS_MALE_41-66']
# ['bra' 'android' 'male' 22 31.0 '19-23' 'BRA_ANDROID_MALE_19-23']
# ['deu' 'android' 'female' 21 31.0 '19-23' 'DEU_ANDROID_FEMALE_19-23']
# ['bra' 'ios' 'male' 21 31.0 '19-23' 'BRA_IOS_MALE_19-23']
# ['bra' 'android' 'female' 20 31.0 '19-23' 'BRA_ANDROID_FEMALE_19-23']
# ['tur' 'android' 'female' 19 31.0 '19-23' 'TUR_ANDROID_FEMALE_19-23']
# ['deu' 'ios' 'male' 30 31.0 '24-30' 'DEU_IOS_MALE_24-30']
# ['usa' 'ios' 'female' 34 30.875 '31-40' 'USA_IOS_FEMALE_31-40']
# ['usa' 'android' 'female' 26 30.77777777777778 '24-30'
#  'USA_ANDROID_FEMALE_24-30']
# ['deu' 'ios' 'female' 15 30.666666666666668 '0-18' 'DEU_IOS_FEMALE_0-18']
# ['fra' 'ios' 'male' 16 30.666666666666668 '0-18' 'FRA_IOS_MALE_0-18']
# ['bra' 'android' 'male' 25 30.428571428571427 '24-30'
#  'BRA_ANDROID_MALE_24-30']
# ['bra' 'ios' 'female' 29 30.428571428571427 '24-30' 'BRA_IOS_FEMALE_24-30']
# ['bra' 'ios' 'male' 66 30.428571428571427 '41-66' 'BRA_IOS_MALE_41-66']
# ['fra' 'ios' 'female' 28 30.428571428571427 '24-30' 'FRA_IOS_FEMALE_24-30']
# ['usa' 'ios' 'female' 50 30.304347826086957 '41-66' 'USA_IOS_FEMALE_41-66']
# ['usa' 'ios' 'male' 33 30.304347826086957 '31-40' 'USA_IOS_MALE_31-40']
# ['usa' 'ios' 'male' 42 30.25 '41-66' 'USA_IOS_MALE_41-66']
# ['fra' 'android' 'male' 15 30.25 '0-18' 'FRA_ANDROID_MALE_0-18']
# ['tur' 'ios' 'female' 17 30.176470588235293 '0-18' 'TUR_IOS_FEMALE_0-18']
# ['bra' 'ios' 'male' 42 30.11111111111111 '41-66' 'BRA_IOS_MALE_41-66']
# ['usa' 'android' 'female' 24 30.05263157894737 '24-30'
#  'USA_ANDROID_FEMALE_24-30']
# ['can' 'android' 'male' 24 29.76923076923077 '24-30'
#  'CAN_ANDROID_MALE_24-30']
# ['bra' 'ios' 'female' 23 29.76923076923077 '19-23' 'BRA_IOS_FEMALE_19-23']
# ['bra' 'android' 'male' 29 29.714285714285715 '24-30'
#  'BRA_ANDROID_MALE_24-30']
# ['can' 'android' 'female' 16 29.689655172413794 '0-18'
#  'CAN_ANDROID_FEMALE_0-18']
# ['bra' 'android' 'male' 16 29.666666666666668 '0-18'
#  'BRA_ANDROID_MALE_0-18']
# ['usa' 'ios' 'female' 35 29.625 '31-40' 'USA_IOS_FEMALE_31-40']
# ['fra' 'ios' 'male' 15 29.0 '0-18' 'FRA_IOS_MALE_0-18']
# ['fra' 'ios' 'male' 27 29.0 '24-30' 'FRA_IOS_MALE_24-30']
# ['bra' 'android' 'male' 53 29.0 '41-66' 'BRA_ANDROID_MALE_41-66']
# ['fra' 'ios' 'male' 38 29.0 '31-40' 'FRA_IOS_MALE_31-40']
# ['can' 'ios' 'male' 32 29.0 '31-40' 'CAN_IOS_MALE_31-40']
# ['usa' 'ios' 'female' 42 29.0 '41-66' 'USA_IOS_FEMALE_41-66']
# ['can' 'ios' 'female' 16 29.0 '0-18' 'CAN_IOS_FEMALE_0-18']
# ['deu' 'ios' 'male' 23 29.0 '19-23' 'DEU_IOS_MALE_19-23']
# ['deu' 'ios' 'female' 24 29.0 '24-30' 'DEU_IOS_FEMALE_24-30']
# ['deu' 'android' 'male' 32 29.0 '31-40' 'DEU_ANDROID_MALE_31-40']
# ['deu' 'android' 'male' 24 29.0 '24-30' 'DEU_ANDROID_MALE_24-30']
# ['deu' 'android' 'female' 33 29.0 '31-40' 'DEU_ANDROID_FEMALE_31-40']
# ['usa' 'ios' 'male' 55 29.0 '41-66' 'USA_IOS_MALE_41-66']
# ['tur' 'android' 'female' 56 29.0 '41-66' 'TUR_ANDROID_FEMALE_41-66']
# ['bra' 'ios' 'male' 31 29.0 '31-40' 'BRA_IOS_MALE_31-40']
# ['usa' 'android' 'male' 38 29.0 '31-40' 'USA_ANDROID_MALE_31-40']
# ['usa' 'android' 'male' 57 29.0 '41-66' 'USA_ANDROID_MALE_41-66']
# ['usa' 'android' 'female' 27 29.0 '24-30' 'USA_ANDROID_FEMALE_24-30']
# ['usa' 'android' 'male' 34 29.0 '31-40' 'USA_ANDROID_MALE_31-40']
# ['usa' 'android' 'male' 37 29.0 '31-40' 'USA_ANDROID_MALE_31-40']
# ['bra' 'ios' 'male' 37 29.0 '31-40' 'BRA_IOS_MALE_31-40']
# ['usa' 'android' 'female' 30 29.0 '24-30' 'USA_ANDROID_FEMALE_24-30']
# ['tur' 'android' 'male' 36 29.0 '31-40' 'TUR_ANDROID_MALE_31-40']
# ['tur' 'ios' 'female' 16 29.0 '0-18' 'TUR_IOS_FEMALE_0-18']
# ['bra' 'android' 'male' 28 28.23076923076923 '24-30'
#  'BRA_ANDROID_MALE_24-30']
# ['usa' 'android' 'female' 32 28.166666666666668 '31-40'
#  'USA_ANDROID_FEMALE_31-40']
# ['usa' 'android' 'female' 34 28.0 '31-40' 'USA_ANDROID_FEMALE_31-40']
# ['deu' 'android' 'female' 41 27.75 '41-66' 'DEU_ANDROID_FEMALE_41-66']
# ['fra' 'ios' 'female' 16 27.75 '0-18' 'FRA_IOS_FEMALE_0-18']
# ['bra' 'ios' 'female' 31 27.571428571428573 '31-40' 'BRA_IOS_FEMALE_31-40']
# ['tur' 'ios' 'male' 19 27.333333333333332 '19-23' 'TUR_IOS_MALE_19-23']
# ['fra' 'android' 'female' 19 27.333333333333332 '19-23'
#  'FRA_ANDROID_FEMALE_19-23']
# ['deu' 'android' 'female' 16 27.0 '0-18' 'DEU_ANDROID_FEMALE_0-18']
# ['bra' 'android' 'female' 27 26.142857142857142 '24-30'
#  'BRA_ANDROID_FEMALE_24-30']
# ['usa' 'android' 'male' 24 26.058823529411764 '24-30'
#  'USA_ANDROID_MALE_24-30']
# ['can' 'android' 'female' 15 25.666666666666668 '0-18'
#  'CAN_ANDROID_FEMALE_0-18']
# ['tur' 'ios' 'female' 38 25.666666666666668 '31-40' 'TUR_IOS_FEMALE_31-40']
# ['fra' 'android' 'male' 21 25.666666666666668 '19-23'
#  'FRA_ANDROID_MALE_19-23']
# ['usa' 'android' 'male' 65 25.666666666666668 '41-66'
#  'USA_ANDROID_MALE_41-66']
# ['fra' 'ios' 'female' 25 25.0 '24-30' 'FRA_IOS_FEMALE_24-30']
# ['bra' 'android' 'female' 34 24.0 '31-40' 'BRA_ANDROID_FEMALE_31-40']
# ['tur' 'android' 'female' 29 24.0 '24-30' 'TUR_ANDROID_FEMALE_24-30']
# ['usa' 'ios' 'male' 36 24.0 '31-40' 'USA_IOS_MALE_31-40']
# ['usa' 'ios' 'male' 29 24.0 '24-30' 'USA_IOS_MALE_24-30']
# ['bra' 'android' 'female' 28 22.333333333333332 '24-30'
#  'BRA_ANDROID_FEMALE_24-30']
# ['tur' 'ios' 'male' 21 22.333333333333332 '19-23' 'TUR_IOS_MALE_19-23']
# ['usa' 'android' 'male' 29 22.333333333333332 '24-30'
#  'USA_ANDROID_MALE_24-30']
# ['bra' 'ios' 'male' 36 22.333333333333332 '31-40' 'BRA_IOS_MALE_31-40']
# ['bra' 'android' 'male' 23 21.5 '19-23' 'BRA_ANDROID_MALE_19-23']
# ['tur' 'android' 'male' 21 19.0 '19-23' 'TUR_ANDROID_MALE_19-23']
# ['tur' 'ios' 'male' 47 19.0 '41-66' 'TUR_IOS_MALE_41-66']
# ['bra' 'ios' 'female' 34 19.0 '31-40' 'BRA_IOS_FEMALE_31-40']
# ['bra' 'ios' 'male' 47 19.0 '41-66' 'BRA_IOS_MALE_41-66']
# ['usa' 'ios' 'female' 38 19.0 '31-40' 'USA_IOS_FEMALE_31-40']
# ['usa' 'ios' 'female' 30 19.0 '24-30' 'USA_IOS_FEMALE_24-30']
# ['can' 'android' 'female' 27 19.0 '24-30' 'CAN_ANDROID_FEMALE_24-30']
# ['fra' 'android' 'male' 18 19.0 '0-18' 'FRA_ANDROID_MALE_0-18']
# ['deu' 'android' 'male' 26 9.0 '24-30' 'DEU_ANDROID_MALE_24-30']

# %%
agg_df["customers_level_based"] = [row[0].upper() + "_" + row[1].upper() + "_" + row[2].upper() + "_" + row[5].upper() for row in agg_df.values]
agg_df.head()
# Out:
#   COUNTRY   SOURCE     SEX  AGE  PRICE AGE_CAT     customers_level_based
# 0     bra  android    male   46   59.0   41-66    BRA_ANDROID_MALE_41-66
# 1     usa  android    male   36   59.0   31-40    USA_ANDROID_MALE_31-40
# 2     fra  android  female   24   59.0   24-30  FRA_ANDROID_FEMALE_24-30
# 3     usa      ios    male   32   54.0   31-40        USA_IOS_MALE_31-40
# 4     deu  android  female   36   49.0   31-40  DEU_ANDROID_FEMALE_31-40

# %%
agg_df = agg_df[["customers_level_based", "PRICE"]]
agg_df.head()
# Out:
#       customers_level_based  PRICE
# 0    BRA_ANDROID_MALE_41-66   59.0
# 1    USA_ANDROID_MALE_31-40   59.0
# 2  FRA_ANDROID_FEMALE_24-30   59.0
# 3        USA_IOS_MALE_31-40   54.0
# 4  DEU_ANDROID_FEMALE_31-40   49.0

# %%
for i in agg_df["customers_level_based"].values:
    print(i.split("_"))
# Out:
# ['BRA', 'ANDROID', 'MALE', '41-66']
# ['USA', 'ANDROID', 'MALE', '31-40']
# ['FRA', 'ANDROID', 'FEMALE', '24-30']
# ['USA', 'IOS', 'MALE', '31-40']
# ['DEU', 'ANDROID', 'FEMALE', '31-40']
# ['DEU', 'ANDROID', 'FEMALE', '41-66']
# ['DEU', 'IOS', 'MALE', '19-23']
# ['USA', 'ANDROID', 'FEMALE', '41-66']
# ['FRA', 'IOS', 'MALE', '19-23']
# ['USA', 'IOS', 'MALE', '41-66']
# ['DEU', 'ANDROID', 'MALE', '0-18']
# ['BRA', 'ANDROID', 'FEMALE', '24-30']
# ['USA', 'ANDROID', 'FEMALE', '41-66']
# ['TUR', 'IOS', 'MALE', '24-30']
# ['DEU', 'ANDROID', 'MALE', '31-40']
# ['TUR', 'IOS', 'FEMALE', '0-18']
# ['BRA', 'ANDROID', 'FEMALE', '41-66']
# ['BRA', 'IOS', 'FEMALE', '19-23']
# ['TUR', 'ANDROID', 'FEMALE', '31-40']
# ['BRA', 'ANDROID', 'FEMALE', '31-40']
# ['TUR', 'IOS', 'MALE', '31-40']
# ['TUR', 'ANDROID', 'MALE', '0-18']
# ['USA', 'IOS', 'MALE', '24-30']
# ['BRA', 'IOS', 'MALE', '41-66']
# ['DEU', 'ANDROID', 'MALE', '19-23']
# ['USA', 'IOS', 'MALE', '24-30']
# ['TUR', 'ANDROID', 'FEMALE', '0-18']
# ['USA', 'ANDROID', 'MALE', '41-66']
# ['TUR', 'ANDROID', 'MALE', '24-30']
# ['USA', 'IOS', 'FEMALE', '41-66']
# ['FRA', 'ANDROID', 'MALE', '19-23']
# ['USA', 'IOS', 'MALE', '31-40']
# ['TUR', 'ANDROID', 'FEMALE', '0-18']
# ['FRA', 'IOS', 'MALE', '0-18']
# ['TUR', 'IOS', 'FEMALE', '19-23']
# ['TUR', 'ANDROID', 'FEMALE', '31-40']
# ['TUR', 'ANDROID', 'MALE', '24-30']
# ['FRA', 'ANDROID', 'MALE', '19-23']
# ['BRA', 'ANDROID', 'MALE', '24-30']
# ['CAN', 'ANDROID', 'MALE', '24-30']
# ['CAN', 'ANDROID', 'MALE', '19-23']
# ['USA', 'ANDROID', 'MALE', '41-66']
# ['TUR', 'ANDROID', 'MALE', '24-30']
# ['BRA', 'ANDROID', 'MALE', '31-40']
# ['BRA', 'ANDROID', 'MALE', '0-18']
# ['USA', 'IOS', 'FEMALE', '19-23']
# ['TUR', 'ANDROID', 'MALE', '41-66']
# ['BRA', 'IOS', 'FEMALE', '19-23']
# ['USA', 'IOS', 'MALE', '41-66']
# ['BRA', 'IOS', 'FEMALE', '24-30']
# ['DEU', 'ANDROID', 'FEMALE', '31-40']
# ['DEU', 'IOS', 'MALE', '0-18']
# ['FRA', 'ANDROID', 'FEMALE', '19-23']
# ['FRA', 'ANDROID', 'MALE', '31-40']
# ['TUR', 'IOS', 'FEMALE', '31-40']
# ['FRA', 'IOS', 'MALE', '41-66']
# ['BRA', 'ANDROID', 'FEMALE', '31-40']
# ['TUR', 'IOS', 'MALE', '0-18']
# ['BRA', 'IOS', 'FEMALE', '41-66']
# ['TUR', 'ANDROID', 'MALE', '0-18']
# ['TUR', 'ANDROID', 'FEMALE', '41-66']
# ['BRA', 'ANDROID', 'FEMALE', '0-18']
# ['USA', 'IOS', 'MALE', '19-23']
# ['USA', 'IOS', 'FEMALE', '0-18']
# ['FRA', 'IOS', 'MALE', '31-40']
# ['TUR', 'ANDROID', 'MALE', '0-18']
# ['DEU', 'ANDROID', 'MALE', '31-40']
# ['USA', 'IOS', 'FEMALE', '24-30']
# ['DEU', 'IOS', 'FEMALE', '0-18']
# ['CAN', 'IOS', 'MALE', '0-18']
# ['CAN', 'ANDROID', 'MALE', '41-66']
# ['BRA', 'ANDROID', 'FEMALE', '24-30']
# ['TUR', 'ANDROID', 'FEMALE', '24-30']
# ['CAN', 'IOS', 'MALE', '0-18']
# ['BRA', 'IOS', 'MALE', '31-40']
# ['FRA', 'ANDROID', 'FEMALE', '0-18']
# ['DEU', 'IOS', 'FEMALE', '0-18']
# ['CAN', 'ANDROID', 'FEMALE', '0-18']
# ['TUR', 'IOS', 'FEMALE', '19-23']
# ['DEU', 'ANDROID', 'MALE', '19-23']
# ['BRA', 'ANDROID', 'FEMALE', '19-23']
# ['USA', 'ANDROID', 'FEMALE', '31-40']
# ['BRA', 'IOS', 'MALE', '19-23']
# ['BRA', 'ANDROID', 'MALE', '0-18']
# ['BRA', 'ANDROID', 'MALE', '24-30']
# ['USA', 'ANDROID', 'MALE', '24-30']
# ['TUR', 'ANDROID', 'FEMALE', '19-23']
# ['DEU', 'IOS', 'MALE', '41-66']
# ['BRA', 'ANDROID', 'FEMALE', '41-66']
# ['BRA', 'IOS', 'MALE', '0-18']
# ['USA', 'IOS', 'FEMALE', '24-30']
# ['BRA', 'IOS', 'FEMALE', '0-18']
# ['BRA', 'IOS', 'MALE', '31-40']
# ['FRA', 'ANDROID', 'FEMALE', '0-18']
# ['USA', 'ANDROID', 'MALE', '19-23']
# ['BRA', 'IOS', 'FEMALE', '0-18']
# ['BRA', 'ANDROID', 'MALE', '41-66']
# ['BRA', 'ANDROID', 'FEMALE', '24-30']
# ['USA', 'ANDROID', 'MALE', '24-30']
# ['TUR', 'ANDROID', 'FEMALE', '41-66']
# ['USA', 'IOS', 'FEMALE', '24-30']
# ['DEU', 'IOS', 'FEMALE', '24-30']
# ['CAN', 'ANDROID', 'MALE', '0-18']
# ['BRA', 'ANDROID', 'FEMALE', '0-18']
# ['TUR', 'ANDROID', 'MALE', '24-30']
# ['USA', 'ANDROID', 'MALE', '41-66']
# ['USA', 'IOS', 'FEMALE', '19-23']
# ['USA', 'ANDROID', 'FEMALE', '19-23']
# ['FRA', 'IOS', 'MALE', '19-23']
# ['FRA', 'ANDROID', 'MALE', '41-66']
# ['BRA', 'ANDROID', 'MALE', '41-66']
# ['TUR', 'ANDROID', 'MALE', '19-23']
# ['BRA', 'ANDROID', 'FEMALE', '24-30']
# ['USA', 'ANDROID', 'FEMALE', '31-40']
# ['USA', 'IOS', 'FEMALE', '24-30']
# ['BRA', 'ANDROID', 'FEMALE', '0-18']
# ['TUR', 'IOS', 'FEMALE', '19-23']
# ['DEU', 'IOS', 'FEMALE', '0-18']
# ['USA', 'ANDROID', 'MALE', '41-66']
# ['BRA', 'ANDROID', 'MALE', '19-23']
# ['DEU', 'ANDROID', 'MALE', '31-40']
# ['BRA', 'IOS', 'FEMALE', '31-40']
# ['BRA', 'IOS', 'FEMALE', '41-66']
# ['BRA', 'ANDROID', 'MALE', '24-30']
# ['DEU', 'ANDROID', 'FEMALE', '24-30']
# ['BRA', 'IOS', 'MALE', '0-18']
# ['BRA', 'ANDROID', 'MALE', '19-23']
# ['USA', 'ANDROID', 'FEMALE', '41-66']
# ['BRA', 'ANDROID', 'MALE', '19-23']
# ['BRA', 'ANDROID', 'FEMALE', '19-23']
# ['USA', 'ANDROID', 'MALE', '0-18']
# ['BRA', 'IOS', 'FEMALE', '31-40']
# ['USA', 'IOS', 'MALE', '24-30']
# ['BRA', 'ANDROID', 'FEMALE', '31-40']
# ['USA', 'IOS', 'FEMALE', '19-23']
# ['USA', 'ANDROID', 'FEMALE', '31-40']
# ['FRA', 'IOS', 'MALE', '19-23']
# ['DEU', 'ANDROID', 'FEMALE', '19-23']
# ['CAN', 'IOS', 'MALE', '0-18']
# ['DEU', 'IOS', 'MALE', '0-18']
# ['USA', 'IOS', 'FEMALE', '41-66']
# ['DEU', 'IOS', 'MALE', '24-30']
# ['BRA', 'ANDROID', 'FEMALE', '19-23']
# ['USA', 'ANDROID', 'FEMALE', '0-18']
# ['BRA', 'IOS', 'MALE', '19-23']
# ['USA', 'ANDROID', 'MALE', '19-23']
# ['TUR', 'IOS', 'MALE', '0-18']
# ['USA', 'ANDROID', 'FEMALE', '24-30']
# ['USA', 'IOS', 'MALE', '0-18']
# ['BRA', 'IOS', 'MALE', '31-40']
# ['USA', 'ANDROID', 'MALE', '19-23']
# ['USA', 'ANDROID', 'MALE', '31-40']
# ['USA', 'ANDROID', 'MALE', '31-40']
# ['USA', 'IOS', 'FEMALE', '41-66']
# ['USA', 'ANDROID', 'MALE', '0-18']
# ['FRA', 'ANDROID', 'FEMALE', '0-18']
# ['USA', 'ANDROID', 'FEMALE', '0-18']
# ['USA', 'IOS', 'MALE', '0-18']
# ['BRA', 'ANDROID', 'FEMALE', '31-40']
# ['USA', 'IOS', 'FEMALE', '31-40']
# ['TUR', 'ANDROID', 'FEMALE', '0-18']
# ['DEU', 'ANDROID', 'FEMALE', '24-30']
# ['USA', 'ANDROID', 'MALE', '0-18']
# ['USA', 'ANDROID', 'MALE', '24-30']
# ['BRA', 'IOS', 'FEMALE', '24-30']
# ['USA', 'ANDROID', 'FEMALE', '19-23']
# ['BRA', 'IOS', 'FEMALE', '41-66']
# ['DEU', 'ANDROID', 'FEMALE', '19-23']
# ['USA', 'IOS', 'MALE', '24-30']
# ['FRA', 'IOS', 'MALE', '24-30']
# ['BRA', 'IOS', 'FEMALE', '24-30']
# ['CAN', 'ANDROID', 'FEMALE', '41-66']
# ['USA', 'IOS', 'FEMALE', '19-23']
# ['USA', 'IOS', 'MALE', '19-23']
# ['BRA', 'IOS', 'MALE', '19-23']
# ['TUR', 'IOS', 'FEMALE', '19-23']
# ['TUR', 'IOS', 'FEMALE', '24-30']
# ['TUR', 'IOS', 'FEMALE', '24-30']
# ['DEU', 'IOS', 'FEMALE', '19-23']
# ['TUR', 'IOS', 'FEMALE', '41-66']
# ['DEU', 'ANDROID', 'MALE', '19-23']
# ['BRA', 'IOS', 'FEMALE', '24-30']
# ['USA', 'ANDROID', 'MALE', '0-18']
# ['USA', 'IOS', 'MALE', '41-66']
# ['USA', 'ANDROID', 'FEMALE', '41-66']
# ['FRA', 'ANDROID', 'FEMALE', '31-40']
# ['USA', 'ANDROID', 'MALE', '24-30']
# ['USA', 'ANDROID', 'FEMALE', '24-30']
# ['DEU', 'IOS', 'FEMALE', '19-23']
# ['BRA', 'IOS', 'MALE', '24-30']
# ['USA', 'IOS', 'FEMALE', '0-18']
# ['USA', 'ANDROID', 'FEMALE', '19-23']
# ['BRA', 'IOS', 'MALE', '0-18']
# ['DEU', 'ANDROID', 'FEMALE', '0-18']
# ['BRA', 'ANDROID', 'FEMALE', '31-40']
# ['USA', 'IOS', 'MALE', '0-18']
# ['CAN', 'IOS', 'FEMALE', '0-18']
# ['TUR', 'ANDROID', 'FEMALE', '0-18']
# ['BRA', 'IOS', 'FEMALE', '0-18']
# ['FRA', 'IOS', 'FEMALE', '0-18']
# ['BRA', 'ANDROID', 'FEMALE', '41-66']
# ['BRA', 'IOS', 'MALE', '41-66']
# ['USA', 'ANDROID', 'MALE', '24-30']
# ['BRA', 'ANDROID', 'FEMALE', '24-30']
# ['USA', 'ANDROID', 'FEMALE', '19-23']
# ['BRA', 'ANDROID', 'MALE', '0-18']
# ['BRA', 'IOS', 'FEMALE', '41-66']
# ['USA', 'ANDROID', 'MALE', '41-66']
# ['FRA', 'IOS', 'FEMALE', '31-40']
# ['FRA', 'ANDROID', 'MALE', '24-30']
# ['DEU', 'IOS', 'FEMALE', '31-40']
# ['USA', 'IOS', 'FEMALE', '0-18']
# ['DEU', 'ANDROID', 'MALE', '0-18']
# ['USA', 'IOS', 'MALE', '0-18']
# ['BRA', 'IOS', 'FEMALE', '19-23']
# ['TUR', 'IOS', 'MALE', '0-18']
# ['USA', 'ANDROID', 'MALE', '19-23']
# ['USA', 'IOS', 'FEMALE', '19-23']
# ['USA', 'IOS', 'FEMALE', '24-30']
# ['BRA', 'IOS', 'MALE', '0-18']
# ['USA', 'ANDROID', 'FEMALE', '0-18']
# ['FRA', 'IOS', 'FEMALE', '31-40']
# ['BRA', 'IOS', 'FEMALE', '0-18']
# ['TUR', 'IOS', 'FEMALE', '19-23']
# ['BRA', 'ANDROID', 'MALE', '24-30']
# ['FRA', 'IOS', 'FEMALE', '0-18']
# ['CAN', 'ANDROID', 'FEMALE', '19-23']
# ['USA', 'ANDROID', 'FEMALE', '0-18']
# ['DEU', 'ANDROID', 'MALE', '0-18']
# ['USA', 'ANDROID', 'MALE', '19-23']
# ['DEU', 'ANDROID', 'FEMALE', '31-40']
# ['USA', 'ANDROID', 'FEMALE', '41-66']
# ['FRA', 'ANDROID', 'MALE', '31-40']
# ['DEU', 'ANDROID', 'FEMALE', '24-30']
# ['FRA', 'ANDROID', 'MALE', '41-66']
# ['BRA', 'IOS', 'FEMALE', '24-30']
# ['DEU', 'ANDROID', 'MALE', '31-40']
# ['TUR', 'ANDROID', 'FEMALE', '19-23']
# ['TUR', 'ANDROID', 'FEMALE', '41-66']
# ['BRA', 'ANDROID', 'FEMALE', '41-66']
# ['BRA', 'IOS', 'FEMALE', '31-40']
# ['BRA', 'ANDROID', 'FEMALE', '0-18']
# ['USA', 'IOS', 'MALE', '19-23']
# ['FRA', 'ANDROID', 'FEMALE', '19-23']
# ['DEU', 'ANDROID', 'FEMALE', '24-30']
# ['DEU', 'ANDROID', 'FEMALE', '0-18']
# ['BRA', 'ANDROID', 'FEMALE', '19-23']
# ['USA', 'IOS', 'MALE', '24-30']
# ['BRA', 'ANDROID', 'MALE', '31-40']
# ['FRA', 'ANDROID', 'FEMALE', '24-30']
# ['USA', 'IOS', 'MALE', '31-40']
# ['CAN', 'IOS', 'FEMALE', '24-30']
# ['CAN', 'ANDROID', 'FEMALE', '19-23']
# ['USA', 'IOS', 'FEMALE', '24-30']
# ['BRA', 'ANDROID', 'MALE', '31-40']
# ['USA', 'IOS', 'FEMALE', '0-18']
# ['DEU', 'ANDROID', 'FEMALE', '41-66']
# ['DEU', 'IOS', 'MALE', '31-40']
# ['USA', 'ANDROID', 'FEMALE', '19-23']
# ['DEU', 'ANDROID', 'MALE', '19-23']
# ['CAN', 'IOS', 'MALE', '24-30']
# ['TUR', 'IOS', 'MALE', '41-66']
# ['CAN', 'IOS', 'MALE', '41-66']
# ['BRA', 'ANDROID', 'MALE', '19-23']
# ['DEU', 'ANDROID', 'FEMALE', '19-23']
# ['BRA', 'IOS', 'MALE', '19-23']
# ['BRA', 'ANDROID', 'FEMALE', '19-23']
# ['TUR', 'ANDROID', 'FEMALE', '19-23']
# ['DEU', 'IOS', 'MALE', '24-30']
# ['USA', 'IOS', 'FEMALE', '31-40']
# ['USA', 'ANDROID', 'FEMALE', '24-30']
# ['DEU', 'IOS', 'FEMALE', '0-18']
# ['FRA', 'IOS', 'MALE', '0-18']
# ['BRA', 'ANDROID', 'MALE', '24-30']
# ['BRA', 'IOS', 'FEMALE', '24-30']
# ['BRA', 'IOS', 'MALE', '41-66']
# ['FRA', 'IOS', 'FEMALE', '24-30']
# ['USA', 'IOS', 'FEMALE', '41-66']
# ['USA', 'IOS', 'MALE', '31-40']
# ['USA', 'IOS', 'MALE', '41-66']
# ['FRA', 'ANDROID', 'MALE', '0-18']
# ['TUR', 'IOS', 'FEMALE', '0-18']
# ['BRA', 'IOS', 'MALE', '41-66']
# ['USA', 'ANDROID', 'FEMALE', '24-30']
# ['CAN', 'ANDROID', 'MALE', '24-30']
# ['BRA', 'IOS', 'FEMALE', '19-23']
# ['BRA', 'ANDROID', 'MALE', '24-30']
# ['CAN', 'ANDROID', 'FEMALE', '0-18']
# ['BRA', 'ANDROID', 'MALE', '0-18']
# ['USA', 'IOS', 'FEMALE', '31-40']
# ['FRA', 'IOS', 'MALE', '0-18']
# ['FRA', 'IOS', 'MALE', '24-30']
# ['BRA', 'ANDROID', 'MALE', '41-66']
# ['FRA', 'IOS', 'MALE', '31-40']
# ['CAN', 'IOS', 'MALE', '31-40']
# ['USA', 'IOS', 'FEMALE', '41-66']
# ['CAN', 'IOS', 'FEMALE', '0-18']
# ['DEU', 'IOS', 'MALE', '19-23']
# ['DEU', 'IOS', 'FEMALE', '24-30']
# ['DEU', 'ANDROID', 'MALE', '31-40']
# ['DEU', 'ANDROID', 'MALE', '24-30']
# ['DEU', 'ANDROID', 'FEMALE', '31-40']
# ['USA', 'IOS', 'MALE', '41-66']
# ['TUR', 'ANDROID', 'FEMALE', '41-66']
# ['BRA', 'IOS', 'MALE', '31-40']
# ['USA', 'ANDROID', 'MALE', '31-40']
# ['USA', 'ANDROID', 'MALE', '41-66']
# ['USA', 'ANDROID', 'FEMALE', '24-30']
# ['USA', 'ANDROID', 'MALE', '31-40']
# ['USA', 'ANDROID', 'MALE', '31-40']
# ['BRA', 'IOS', 'MALE', '31-40']
# ['USA', 'ANDROID', 'FEMALE', '24-30']
# ['TUR', 'ANDROID', 'MALE', '31-40']
# ['TUR', 'IOS', 'FEMALE', '0-18']
# ['BRA', 'ANDROID', 'MALE', '24-30']
# ['USA', 'ANDROID', 'FEMALE', '31-40']
# ['USA', 'ANDROID', 'FEMALE', '31-40']
# ['DEU', 'ANDROID', 'FEMALE', '41-66']
# ['FRA', 'IOS', 'FEMALE', '0-18']
# ['BRA', 'IOS', 'FEMALE', '31-40']
# ['TUR', 'IOS', 'MALE', '19-23']
# ['FRA', 'ANDROID', 'FEMALE', '19-23']
# ['DEU', 'ANDROID', 'FEMALE', '0-18']
# ['BRA', 'ANDROID', 'FEMALE', '24-30']
# ['USA', 'ANDROID', 'MALE', '24-30']
# ['CAN', 'ANDROID', 'FEMALE', '0-18']
# ['TUR', 'IOS', 'FEMALE', '31-40']
# ['FRA', 'ANDROID', 'MALE', '19-23']
# ['USA', 'ANDROID', 'MALE', '41-66']
# ['FRA', 'IOS', 'FEMALE', '24-30']
# ['BRA', 'ANDROID', 'FEMALE', '31-40']
# ['TUR', 'ANDROID', 'FEMALE', '24-30']
# ['USA', 'IOS', 'MALE', '31-40']
# ['USA', 'IOS', 'MALE', '24-30']
# ['BRA', 'ANDROID', 'FEMALE', '24-30']
# ['TUR', 'IOS', 'MALE', '19-23']
# ['USA', 'ANDROID', 'MALE', '24-30']
# ['BRA', 'IOS', 'MALE', '31-40']
# ['BRA', 'ANDROID', 'MALE', '19-23']
# ['TUR', 'ANDROID', 'MALE', '19-23']
# ['TUR', 'IOS', 'MALE', '41-66']
# ['BRA', 'IOS', 'FEMALE', '31-40']
# ['BRA', 'IOS', 'MALE', '41-66']
# ['USA', 'IOS', 'FEMALE', '31-40']
# ['USA', 'IOS', 'FEMALE', '24-30']
# ['CAN', 'ANDROID', 'FEMALE', '24-30']
# ['FRA', 'ANDROID', 'MALE', '0-18']
# ['DEU', 'ANDROID', 'MALE', '24-30']

# %%
agg_df = agg_df.groupby("customers_level_based").agg({"PRICE": "mean"})

# %%
agg_df = agg_df.reset_index()
agg_df.head()
# Out:
#       customers_level_based      PRICE
# 0   BRA_ANDROID_FEMALE_0-18  35.645303
# 1  BRA_ANDROID_FEMALE_19-23  34.077340
# 2  BRA_ANDROID_FEMALE_24-30  33.863946
# 3  BRA_ANDROID_FEMALE_31-40  34.898326
# 4  BRA_ANDROID_FEMALE_41-66  36.737179

# %%
agg_df["customers_level_based"].value_counts()
agg_df.head()
# Out:
#       customers_level_based      PRICE
# 0   BRA_ANDROID_FEMALE_0-18  35.645303
# 1  BRA_ANDROID_FEMALE_19-23  34.077340
# 2  BRA_ANDROID_FEMALE_24-30  33.863946
# 3  BRA_ANDROID_FEMALE_31-40  34.898326
# 4  BRA_ANDROID_FEMALE_41-66  36.737179

# %%
agg_df['SEGMENT']=pd.qcut(agg_df['PRICE'],4,labels=["D","C","B","A"])

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

agg_df.groupby('SEGMENT').agg({'PRICE':['mean','max','sum']})
# Out:
#              PRICE
#               mean        max          sum
# SEGMENT
# D        29.206780  32.333333   817.789833
# C        33.509674  34.077340   904.761209
# B        34.999645  36.000000   944.990411
# A        38.691234  45.428571  1044.663328

# %% [markdown]
# * TASK 7: Segment new customers (USA_ANDROID_MALE_0_18).

# %%
agg_df["SEGMENT"] = pd.qcut(agg_df["PRICE"], 4, labels=["D", "C", "B", "A"])
agg_df.head(30)
# Out:
#        customers_level_based      PRICE SEGMENT
# 0    BRA_ANDROID_FEMALE_0-18  35.645303       B
# 1   BRA_ANDROID_FEMALE_19-23  34.077340       C
# 2   BRA_ANDROID_FEMALE_24-30  33.863946       C
# 3   BRA_ANDROID_FEMALE_31-40  34.898326       B
# 4   BRA_ANDROID_FEMALE_41-66  36.737179       A
# 5      BRA_ANDROID_MALE_0-18  34.805861       B
# 6     BRA_ANDROID_MALE_19-23  31.673243       D
# 7     BRA_ANDROID_MALE_24-30  33.413919       C
# 8     BRA_ANDROID_MALE_31-40  34.327381       B
# 9     BRA_ANDROID_MALE_41-66  40.041667       A
# 10       BRA_IOS_FEMALE_0-18  34.900410       B
# 11      BRA_IOS_FEMALE_19-23  36.403846       A
# 12      BRA_IOS_FEMALE_24-30  34.015873       C
# 13      BRA_IOS_FEMALE_31-40  29.875902       D
# 14      BRA_IOS_FEMALE_41-66  35.340909       B
# 15         BRA_IOS_MALE_0-18  34.664559       B
# 16        BRA_IOS_MALE_19-23  34.266043       B
# 17        BRA_IOS_MALE_24-30  33.864865       C
# 18        BRA_IOS_MALE_31-40  31.566138       D
# 19        BRA_IOS_MALE_41-66  31.083694       D
# 20   CAN_ANDROID_FEMALE_0-18  30.896552       D
# 21  CAN_ANDROID_FEMALE_19-23  32.014706       D
# 22  CAN_ANDROID_FEMALE_24-30  19.000000       D
# 23  CAN_ANDROID_FEMALE_41-66  34.000000       C
# 24     CAN_ANDROID_MALE_0-18  36.000000       B
# 25    CAN_ANDROID_MALE_19-23  40.111111       A
# 26    CAN_ANDROID_MALE_24-30  35.009615       B
# 27    CAN_ANDROID_MALE_41-66  37.571429       A
# 28       CAN_IOS_FEMALE_0-18  31.352941       D
# 29      CAN_IOS_FEMALE_24-30  31.727273       D

# %%
agg_df.groupby("SEGMENT").agg({"PRICE": "mean"})
# Out:
#              PRICE
# SEGMENT
# D        29.206780
# C        33.509674
# B        34.999645
# A        38.691234
